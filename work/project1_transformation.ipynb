# %% [markdown]
# # Project 1
# ### Transformation and enrichment part (points 2,3)

# %%
import os
from pathlib import Path
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

if Path("data").exists():
    DATA_BASE = Path("data")
elif Path("../data").exists():
    DATA_BASE = Path("../data")
else:
    DATA_BASE = Path("/home/jovyan/data")

INBOX = DATA_BASE / "inbox"

spark = (
    SparkSession.builder
    .appName("Project1_Group_H")
    .enableHiveSupport()
    .config("spark.sql.autoBroadcastJoinThreshold", "10MB")
    .getOrCreate()
)

print(spark.version)

trip_files = sorted(str(p) for p in INBOX.glob("yellow_tripdata_*.parquet"))
print(f"files: {[Path(f).name for f in trip_files]}")

#read trips parquets
df_raw = (
    spark.read
    .format("parquet")
    .load(trip_files)
    .withColumn("source_file", F.input_file_name())
)

#read zones parquts
zones_raw = spark.read.parquet(str(INBOX / "taxi_zone_lookup.parquet"))

print(f"trips count: {df_raw.count()}")
print(f"zone count: {zones_raw.count()}")
# Out:
# 4.1.0
# files: ['yellow_tripdata_2025-01.parquet', 'yellow_tripdata_2025-02.parquet']
# trips count: 7052769
# zone count: 265

# %% [markdown]
# ### Parse and cast types

# %%
df_casted = df_raw.select(
    F.col("VendorID").cast("int"),
    # timestamps
    F.col("tpep_pickup_datetime").cast("timestamp").alias("pickup_datetime"),
    F.col("tpep_dropoff_datetime").cast("timestamp").alias("dropoff_datetime"),

    # ints
    F.col("PULocationID").cast("int"),
    F.col("DOLocationID").cast("int"),
    F.col("passenger_count").cast("int"),

    # floats
    F.col("trip_distance").cast("double"),
    F.col("fare_amount").cast("double"),
    F.col("total_amount").cast("double"),

    #metadata    
    F.col("source_file"),
    F.current_timestamp().alias("ingested_at")
)

df_casted.printSchema()
df_casted.show(3, truncate=False)
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- pickup_datetime: timestamp (nullable = true)
#  |-- dropoff_datetime: timestamp (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- source_file: string (nullable = false)
#  |-- ingested_at: timestamp (nullable = false)
#
# +--------+-------------------+-------------------+------------+------------+---------------+-------------+-----------+------------+--------------------------------------------------------------+--------------------------+
# |VendorID|pickup_datetime    |dropoff_datetime   |PULocationID|DOLocationID|passenger_count|trip_distance|fare_amount|total_amount|source_file                                                   |ingested_at               |
# +--------+-------------------+-------------------+------------+------------+---------------+-------------+-----------+------------+--------------------------------------------------------------+--------------------------+
# |2       |2025-02-01 00:12:18|2025-02-01 00:32:33|246         |79          |3              |3.12         |19.8       |30.66       |file:///home/jovyan/data/inbox/yellow_tripdata_2025-02.parquet|2026-03-01 22:07:16.763958|
# |2       |2025-02-01 00:40:04|2025-02-01 00:49:15|114         |79          |1              |1.4          |10.0       |18.9        |file:///home/jovyan/data/inbox/yellow_tripdata_2025-02.parquet|2026-03-01 22:07:16.763958|
# |1       |2025-02-01 00:06:09|2025-02-01 00:11:51|211         |144         |0              |0.4          |6.5        |13.25       |file:///home/jovyan/data/inbox/yellow_tripdata_2025-02.parquet|2026-03-01 22:07:16.763958|
# +--------+-------------------+-------------------+------------+------------+---------------+-------------+-----------+------------+--------------------------------------------------------------+--------------------------+
# only showing top 3 rows

# %%
zones_raw.show(5)
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 5 rows

# %% [markdown]
# ### Clean
#
# Rules which we discussed during meetup.
#
# | # | Rule | Column(s) | Condition kept |
# |---|------|-----------|----------------|
# | 1 | Non-null timestamps | `pickup_datetime`, `dropoff_datetime` | `isNotNull()` |
# | 2 | Chronological trip | both timestamps | `dropoff > pickup` |
# | 3 | Positive distance | `trip_distance` | `> 0` |
# | 4 | Valid passenger count | `passenger_count` | `> 0` |
# | 5 | Positive fare | `total_amount`, `fare_amount` | `> 0` |
# | 6 | Valid location IDs | `PULocationID`, `DOLocationID` | `isNotNull()` |

# %%
df_cleaned = df_casted.filter(
    F.col("pickup_datetime").isNotNull() &
    F.col("dropoff_datetime").isNotNull() &
    (F.col("dropoff_datetime") > F.col("pickup_datetime")) &
    (F.col("trip_distance") > 0) &
    (F.col("passenger_count") > 0) &
    ((F.col("total_amount") > 0) & (F.col("fare_amount") > 0)) &
    F.col("PULocationID").isNotNull() &
    F.col("DOLocationID").isNotNull()
)

raw_count = df_casted.count()
after_clean_count = df_cleaned.count()

print(f"Rows input: {raw_count}")
print(f"Rows after clean: {after_clean_count}(removed {raw_count - after_clean_count})")
# Out:
# Rows input: 7052769
# Rows after clean: 5472446(removed 1580323)

# %%
print("trip_distance <= 0:")
df_casted.filter(
    F.col("trip_distance") <= 0
).select(
    "pickup_datetime", "dropoff_datetime", "trip_distance", "passenger_count", "total_amount"
).show(2, truncate=False)

print("passenger_count < 1:")
df_casted.filter(
    F.col("passenger_count") < 1
).select(
    "pickup_datetime", "dropoff_datetime", "trip_distance", "passenger_count", "total_amount"
).show(2, truncate=False)

print("dropoff_datetime <= pickup_datetime:")
df_casted.filter(
    F.col("pickup_datetime").isNotNull() &
    (F.col("dropoff_datetime") <= F.col("pickup_datetime"))
).select(
    "pickup_datetime", "dropoff_datetime", "trip_distance", "passenger_count"
).show(1, truncate=False)
df_casted.filter(
    F.col("pickup_datetime").isNotNull() &
    (F.col("dropoff_datetime") < F.col("pickup_datetime"))
).select(
    "pickup_datetime", "dropoff_datetime", "trip_distance", "passenger_count"
).show(1, truncate=False)
# Out:
# trip_distance <= 0:
# +-------------------+-------------------+-------------+---------------+------------+
# |pickup_datetime    |dropoff_datetime   |trip_distance|passenger_count|total_amount|
# +-------------------+-------------------+-------------+---------------+------------+
# |2025-02-01 00:30:36|2025-02-01 00:31:28|0.0          |1              |8.75        |
# |2025-02-01 00:35:53|2025-02-01 00:35:58|0.0          |1              |17.25       |
# +-------------------+-------------------+-------------+---------------+------------+
# only showing top 2 rows
# passenger_count < 1:
# +-------------------+-------------------+-------------+---------------+------------+
# |pickup_datetime    |dropoff_datetime   |trip_distance|passenger_count|total_amount|
# +-------------------+-------------------+-------------+---------------+------------+
# |2025-02-01 00:06:09|2025-02-01 00:11:51|0.4          |0              |13.25       |
# |2025-02-01 00:15:13|2025-02-01 00:20:19|0.7          |0              |14.95       |
# +-------------------+-------------------+-------------+---------------+------------+
# only showing top 2 rows
# dropoff_datetime <= pickup_datetime:
# +-------------------+-------------------+-------------+---------------+
# |pickup_datetime    |dropoff_datetime   |trip_distance|passenger_count|
# +-------------------+-------------------+-------------+---------------+
# |2025-02-01 00:01:10|2025-02-01 00:01:10|1.14         |1              |
# +-------------------+-------------------+-------------+---------------+
# only showing top 1 row
# +-------------------+-------------------+-------------+---------------+
# |pickup_datetime    |dropoff_datetime   |trip_distance|passenger_count|
# +-------------------+-------------------+-------------+---------------+
# |2025-02-01 14:45:00|2025-02-01 13:49:59|3.4          |1              |
# +-------------------+-------------------+-------------+---------------+
# only showing top 1 row

# %% [markdown]
# # Do we need to clean zones as well? How should we handle them?

# %% [markdown]
# ### Deduplication
# **Key:** `(pickup_datetime, dropoff_datetime, PULocationID, DOLocationID, trip_distance, vendorID)`
# Two real trips cannot share the same origin, destination, exact times, and distance.

# %% [markdown]
# ### Is this wrong? is the dataset perfect or am i doing it wrong?

# %%
deduplication_key = [
    "pickup_datetime",
    "dropoff_datetime",
    "PULocationID",
    "DOLocationID",
    "trip_distance",
    "VendorID",
]

df_dedup = df_cleaned.dropDuplicates(deduplication_key)

after_dedup_count = df_dedup.count()
print(f"Rows after clean: {after_clean_count}")
print(f"Rows after dedup: {after_dedup_count}(removed {after_clean_count - after_dedup_count} duplicates)")
# Out:
# Rows after clean: 5472446
# Rows after dedup: 5472446(removed 0 duplicates)

# %% [markdown]
# ### derived columns

# %%
df_derived = df_dedup.selectExpr(
    "*",
    "round((unix_timestamp(dropoff_datetime) - unix_timestamp(pickup_datetime)) / 60.0, 2) AS trip_duration_minutes",
    "to_date(pickup_datetime) AS pickup_date"
)

df_derived.select(
    "pickup_datetime", "dropoff_datetime",
    "trip_distance", "trip_duration_minutes", "pickup_date"
).show(5, truncate=False)
# Out:
# +-------------------+-------------------+-------------+---------------------+-----------+
# |pickup_datetime    |dropoff_datetime   |trip_distance|trip_duration_minutes|pickup_date|
# +-------------------+-------------------+-------------+---------------------+-----------+
# |2025-02-01 00:26:21|2025-02-01 00:36:43|2.65         |10.37                |2025-02-01 |
# |2025-02-01 00:13:13|2025-02-01 00:31:36|2.28         |18.38                |2025-02-01 |
# |2025-02-01 00:19:55|2025-02-01 00:40:20|3.71         |20.42                |2025-02-01 |
# |2025-02-01 00:03:37|2025-02-01 00:18:05|3.41         |14.47                |2025-02-01 |
# |2025-02-01 00:29:11|2025-02-01 00:38:09|2.63         |8.97                 |2025-02-01 |
# +-------------------+-------------------+-------------+---------------------+-----------+
# only showing top 5 rows

# %% [markdown]
# ### Zone Enrichment
# Cast column names for the zones once, then create separate pickup and dropoff views. the zone table has 265 rows therefore smaller than main data aand we'll use broacast join

# %%
zones = zones_raw.select(
    F.col("LocationID").cast("int"),
    F.col("Zone").alias("zone_name"),
    F.col("Borough").alias("borough")
)

pickup_zones = zones.select(
    F.col("LocationID").alias("PULocationID"),
    F.col("zone_name").alias("pickup_zone"),
    F.col("borough").alias("pickup_borough")
)

dropoff_zones = zones.select(
    F.col("LocationID").alias("DOLocationID"),
    F.col("zone_name").alias("dropoff_zone"),
    F.col("borough").alias("dropoff_borough")
)

print("autoBroadcastJoinThreshold:", spark.conf.get("spark.sql.autoBroadcastJoinThreshold"))

df_enriched = (
    df_derived
    .join(F.broadcast(pickup_zones), on="PULocationID", how="left")
    .join(F.broadcast(dropoff_zones), on="DOLocationID", how="left")
)

df_enriched.select(
    "pickup_datetime", 
    "PULocationID", 
    "pickup_zone", 
    "pickup_borough",
    "DOLocationID", 
    "dropoff_zone", 
    "dropoff_borough"
).show(5, truncate=False)
# Out:
# autoBroadcastJoinThreshold: 10MB
# +-------------------+------------+------------+--------------+------------+------------------------+---------------+
# |pickup_datetime    |PULocationID|pickup_zone |pickup_borough|DOLocationID|dropoff_zone            |dropoff_borough|
# +-------------------+------------+------------+--------------+------------+------------------------+---------------+
# |2025-02-01 00:26:21|79          |East Village|Manhattan     |161         |Midtown Center          |Manhattan      |
# |2025-02-01 00:13:13|249         |West Village|Manhattan     |87          |Financial District North|Manhattan      |
# |2025-02-01 00:19:55|48          |Clinton East|Manhattan     |87          |Financial District North|Manhattan      |
# |2025-02-01 00:03:37|90          |Flatiron    |Manhattan     |236         |Upper East Side North   |Manhattan      |
# |2025-02-01 00:29:11|170         |Murray Hill |Manhattan     |236         |Upper East Side North   |Manhattan      |
# +-------------------+------------+------------+--------------+------------+------------------------+---------------+
# only showing top 5 rows

# %% [markdown]
# ### End result
#
# Required output fields must include at least:
# * pickup and dropoff timestamps
# * pickup and dropoff LocationID
# * pickup and dropoff zone name (from lookup)
# * passenger_count, trip_distance
# * derived: trip_duration_minutes, pickup_date
# * metadata: source_file, ingested_at

# %%
df_output = df_enriched.select(
    "VendorID",
    "pickup_datetime",
    "dropoff_datetime",
    "PULocationID",
    "DOLocationID",
    "pickup_zone",
    "pickup_borough",
    "dropoff_zone",
    "dropoff_borough",
    "passenger_count",
    "trip_distance",
    "fare_amount",
    "total_amount",
    "trip_duration_minutes",
    "pickup_date",
    "source_file",
    "ingested_at"
)

df_output.printSchema()
df_output.show(5, truncate=False)

final_count = df_output.count()
print(f"Input(raw): {raw_count}")
print(f"After cleaning: {after_clean_count}")
print(f"After dedup: {after_dedup_count}")
print(f"Final output: {final_count}")
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- pickup_datetime: timestamp (nullable = true)
#  |-- dropoff_datetime: timestamp (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- pickup_zone: string (nullable = true)
#  |-- pickup_borough: string (nullable = true)
#  |-- dropoff_zone: string (nullable = true)
#  |-- dropoff_borough: string (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- trip_duration_minutes: decimal(24,2) (nullable = true)
#  |-- pickup_date: date (nullable = true)
#  |-- source_file: string (nullable = false)
#  |-- ingested_at: timestamp (nullable = false)
#
# +--------+-------------------+-------------------+------------+------------+--------------+--------------+--------------+---------------+---------------+-------------+-----------+------------+---------------------+-----------+--------------------------------------------------------------+--------------------------+
# |VendorID|pickup_datetime    |dropoff_datetime   |PULocationID|DOLocationID|pickup_zone   |pickup_borough|dropoff_zone  |dropoff_borough|passenger_count|trip_distance|fare_amount|total_amount|trip_duration_minutes|pickup_date|source_file                                                   |ingested_at               |
# +--------+-------------------+-------------------+------------+------------+--------------+--------------+--------------+---------------+---------------+-------------+-----------+------------+---------------------+-----------+--------------------------------------------------------------+--------------------------+
# |2       |2025-01-30 15:04:14|2025-01-30 15:04:22|1           |1           |Newark Airport|EWR           |Newark Airport|EWR            |1              |0.01         |120.0      |137.94      |0.13                 |2025-01-30 |file:///home/jovyan/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-01 22:14:05.108884|
# |2       |2025-02-12 07:23:40|2025-02-12 07:23:50|1           |1           |Newark Airport|EWR           |Newark Airport|EWR            |1              |0.01         |120.0      |121.0       |0.17                 |2025-02-12 |file:///home/jovyan/data/inbox/yellow_tripdata_2025-02.parquet|2026-03-01 22:14:05.108884|
# |2       |2025-01-17 07:23:50|2025-01-17 07:24:01|1           |1           |Newark Airport|EWR           |Newark Airport|EWR            |1              |0.02         |115.0      |145.0       |0.18                 |2025-01-17 |file:///home/jovyan/data/inbox/yellow_tripdata_2025-01.parquet|2026-03-01 22:14:05.108884|
# |2       |2025-02-01 05:16:07|2025-02-01 05:16:14|1           |1           |Newark Airport|EWR           |Newark Airport|EWR            |2              |0.02         |90.0       |91.05       |0.12                 |2025-02-01 |file:///home/jovyan/data/inbox/yellow_tripdata_2025-02.parquet|2026-03-01 22:14:05.108884|
# |2       |2025-02-06 16:12:55|2025-02-06 16:13:00|1           |1           |Newark Airport|EWR           |Newark Airport|EWR            |1              |0.03         |127.0      |153.6       |0.08                 |2025-02-06 |file:///home/jovyan/data/inbox/yellow_tripdata_2025-02.parquet|2026-03-01 22:14:05.108884|
# +--------+-------------------+-------------------+------------+------------+--------------+--------------+--------------+---------------+---------------+-------------+-----------+------------+---------------------+-----------+--------------------------------------------------------------+--------------------------+
# only showing top 5 rows
# Input(raw): 7052769
# After cleaning: 5472446
# After dedup: 5472446
# Final output: 5472446

# %%
df_output.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project ['VendorID, 'pickup_datetime, 'dropoff_datetime, 'PULocationID, 'DOLocationID, 'pickup_zone, 'pickup_borough, 'dropoff_zone, 'dropoff_borough, 'passenger_count, 'trip_distance, 'fare_amount, 'total_amount, 'trip_duration_minutes, 'pickup_date, 'source_file, 'ingested_at]
# +- Project [DOLocationID#64, PULocationID#63, VendorID#62, pickup_datetime#59, dropoff_datetime#60, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, source_file#21, ingested_at#61, trip_duration_minutes#230, pickup_date#231, pickup_zone#262, pickup_borough#263, dropoff_zone#265, dropoff_borough#266]
#    +- Join LeftOuter, (DOLocationID#64 = DOLocationID#264)
#       :- Project [PULocationID#63, VendorID#62, pickup_datetime#59, dropoff_datetime#60, DOLocationID#64, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, source_file#21, ingested_at#61, trip_duration_minutes#230, pickup_date#231, pickup_zone#262, pickup_borough#263]
#       :  +- Join LeftOuter, (PULocationID#63 = PULocationID#261)
#       :     :- Project [VendorID#62, pickup_datetime#59, dropoff_datetime#60, PULocationID#63, DOLocationID#64, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, source_file#21, ingested_at#61, round((cast((unix_timestamp(dropoff_datetime#60, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_datetime#59, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as decimal(20,0)) / 60.0), 2) AS trip_duration_minutes#230, to_date(pickup_datetime#59, None, Some(Etc/UTC), true) AS pickup_date#231]
#       :     :  +- Deduplicate [DOLocationID#64, PULocationID#63, trip_distance#66, VendorID#62, dropoff_datetime#60, pickup_datetime#59]
#       :     :     +- Filter (((((((isnotnull(pickup_datetime#59) AND isnotnull(dropoff_datetime#60)) AND (dropoff_datetime#60 > pickup_datetime#59)) AND (trip_distance#66 > cast(0 as double))) AND (passenger_count#65 > 0)) AND ((total_amount#68 > cast(0 as double)) AND (fare_amount#67 > cast(0 as double)))) AND isnotnull(PULocationID#63)) AND isnotnull(DOLocationID#64))
#       :     :        +- Project [cast(VendorID#0 as int) AS VendorID#62, cast(tpep_pickup_datetime#1 as timestamp) AS pickup_datetime#59, cast(tpep_dropoff_datetime#2 as timestamp) AS dropoff_datetime#60, cast(PULocationID#7 as int) AS PULocationID#63, cast(DOLocationID#8 as int) AS DOLocationID#64, cast(passenger_count#3L as int) AS passenger_count#65, cast(trip_distance#4 as double) AS trip_distance#66, cast(fare_amount#10 as double) AS fare_amount#67, cast(total_amount#16 as double) AS total_amount#68, source_file#21, current_timestamp() AS ingested_at#61]
#       :     :           +- Project [VendorID#0, tpep_pickup_datetime#1, tpep_dropoff_datetime#2, passenger_count#3L, trip_distance#4, RatecodeID#5L, store_and_fwd_flag#6, PULocationID#7, DOLocationID#8, payment_type#9L, fare_amount#10, extra#11, mta_tax#12, tip_amount#13, tolls_amount#14, improvement_surcharge#15, total_amount#16, congestion_surcharge#17, Airport_fee#18, cbd_congestion_fee#19, input_file_name() AS source_file#21]
#       :     :              +- Relation [VendorID#0,tpep_pickup_datetime#1,tpep_dropoff_datetime#2,passenger_count#3L,trip_distance#4,RatecodeID#5L,store_and_fwd_flag#6,PULocationID#7,DOLocationID#8,payment_type#9L,fare_amount#10,extra#11,mta_tax#12,tip_amount#13,tolls_amount#14,improvement_surcharge#15,total_amount#16,congestion_surcharge#17,Airport_fee#18,cbd_congestion_fee#19] parquet
#       :     +- ResolvedHint (strategy=broadcast)
#       :        +- Project [LocationID#260 AS PULocationID#261, zone_name#258 AS pickup_zone#262, borough#259 AS pickup_borough#263]
#       :           +- Project [cast(LocationID#22L as int) AS LocationID#260, Zone#24 AS zone_name#258, Borough#23 AS borough#259]
#       :              +- Relation [LocationID#22L,Borough#23,Zone#24,service_zone#25] parquet
#       +- ResolvedHint (strategy=broadcast)
#          +- Project [LocationID#271 AS DOLocationID#264, zone_name#272 AS dropoff_zone#265, borough#273 AS dropoff_borough#266]
#             +- Project [cast(LocationID#267L as int) AS LocationID#271, Zone#269 AS zone_name#272, Borough#268 AS borough#273]
#                +- Relation [LocationID#267L,Borough#268,Zone#269,service_zone#270] parquet
#
# == Analyzed Logical Plan ==
# VendorID: int, pickup_datetime: timestamp, dropoff_datetime: timestamp, PULocationID: int, DOLocationID: int, pickup_zone: string, pickup_borough: string, dropoff_zone: string, dropoff_borough: string, passenger_count: int, trip_distance: double, fare_amount: double, total_amount: double, trip_duration_minutes: decimal(24,2), pickup_date: date, source_file: string, ingested_at: timestamp
# Project [VendorID#62, pickup_datetime#59, dropoff_datetime#60, PULocationID#63, DOLocationID#64, pickup_zone#262, pickup_borough#263, dropoff_zone#265, dropoff_borough#266, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, trip_duration_minutes#230, pickup_date#231, source_file#21, ingested_at#61]
# +- Project [DOLocationID#64, PULocationID#63, VendorID#62, pickup_datetime#59, dropoff_datetime#60, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, source_file#21, ingested_at#61, trip_duration_minutes#230, pickup_date#231, pickup_zone#262, pickup_borough#263, dropoff_zone#265, dropoff_borough#266]
#    +- Join LeftOuter, (DOLocationID#64 = DOLocationID#264)
#       :- Project [PULocationID#63, VendorID#62, pickup_datetime#59, dropoff_datetime#60, DOLocationID#64, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, source_file#21, ingested_at#61, trip_duration_minutes#230, pickup_date#231, pickup_zone#262, pickup_borough#263]
#       :  +- Join LeftOuter, (PULocationID#63 = PULocationID#261)
#       :     :- Project [VendorID#62, pickup_datetime#59, dropoff_datetime#60, PULocationID#63, DOLocationID#64, passenger_count#65, trip_distance#66, fare_amount#67, total_amount#68, source_file#21, ingested_at#61, round((cast((unix_timestamp(dropoff_datetime#60, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_datetime#59, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as decimal(20,0)) / 60.0), 2) AS trip_duration_minutes#230, to_date(pickup_datetime#59, None, Some(Etc/UTC), true) AS pickup_date#231]
#       :     :  +- Deduplicate [DOLocationID#64, PULocationID#63, trip_distance#66, VendorID#62, dropoff_datetime#60, pickup_datetime#59]
#       :     :     +- Filter (((((((isnotnull(pickup_datetime#59) AND isnotnull(dropoff_datetime#60)) AND (dropoff_datetime#60 > pickup_datetime#59)) AND (trip_distance#66 > cast(0 as double))) AND (passenger_count#65 > 0)) AND ((total_amount#68 > cast(0 as double)) AND (fare_amount#67 > cast(0 as double)))) AND isnotnull(PULocationID#63)) AND isnotnull(DOLocationID#64))
#       :     :        +- Project [cast(VendorID#0 as int) AS VendorID#62, cast(tpep_pickup_datetime#1 as timestamp) AS pickup_datetime#59, cast(tpep_dropoff_datetime#2 as timestamp) AS dropoff_datetime#60, cast(PULocationID#7 as int) AS PULocationID#63, cast(DOLocationID#8 as int) AS DOLocationID#64, cast(passenger_count#3L as int) AS passenger_count#65, cast(trip_distance#4 as double) AS trip_distance#66, cast(fare_amount#10 as double) AS fare_amount#67, cast(total_amount#16 as double) AS total_amount#68, source_file#21, current_timestamp() AS ingested_at#61]
#       :     :           +- Project [VendorID#0, tpep_pickup_datetime#1, tpep_dropoff_datetime#2, passenger_count#3L, trip_distance#4, RatecodeID#5L, store_and_fwd_flag#6, PULocationID#7, DOLocationID#8, payment_type#9L, fare_amount#10, extra#11, mta_tax#12, tip_amount#13, tolls_amount#14, improvement_surcharge#15, total_amount#16, congestion_surcharge#17, Airport_fee#18, cbd_congestion_fee#19, input_file_name() AS source_file#21]
#       :     :              +- Relation [VendorID#0,tpep_pickup_datetime#1,tpep_dropoff_datetime#2,passenger_count#3L,trip_distance#4,RatecodeID#5L,store_and_fwd_flag#6,PULocationID#7,DOLocationID#8,payment_type#9L,fare_amount#10,extra#11,mta_tax#12,tip_amount#13,tolls_amount#14,improvement_surcharge#15,total_amount#16,congestion_surcharge#17,Airport_fee#18,cbd_congestion_fee#19] parquet
#       :     +- ResolvedHint (strategy=broadcast)
#       :        +- Project [LocationID#260 AS PULocationID#261, zone_name#258 AS pickup_zone#262, borough#259 AS pickup_borough#263]
#       :           +- Project [cast(LocationID#22L as int) AS LocationID#260, Zone#24 AS zone_name#258, Borough#23 AS borough#259]
#       :              +- Relation [LocationID#22L,Borough#23,Zone#24,service_zone#25] parquet
#       +- ResolvedHint (strategy=broadcast)
#          +- Project [LocationID#271 AS DOLocationID#264, zone_name#272 AS dropoff_zone#265, borough#273 AS dropoff_borough#266]
#             +- Project [cast(LocationID#267L as int) AS LocationID#271, Zone#269 AS zone_name#272, Borough#268 AS borough#273]
#                +- Relation [LocationID#267L,Borough#268,Zone#269,service_zone#270] parquet
#
# == Optimized Logical Plan ==
# Project [VendorID#0, pickup_datetime#59, dropoff_datetime#60, PULocationID#7, DOLocationID#8, pickup_zone#262, pickup_borough#263, dropoff_zone#265, dropoff_borough#266, passenger_count#566, trip_distance#4, fare_amount#568, total_amount#570, trip_duration_minutes#230, pickup_date#231, source_file#572, ingested_at#574]
# +- Join LeftOuter, (DOLocationID#8 = DOLocationID#264), rightHint=(strategy=broadcast)
#    :- Project [PULocationID#7, VendorID#0, pickup_datetime#59, dropoff_datetime#60, DOLocationID#8, passenger_count#566, trip_distance#4, fare_amount#568, total_amount#570, source_file#572, ingested_at#574, trip_duration_minutes#230, pickup_date#231, pickup_zone#262, pickup_borough#263]
#    :  +- Join LeftOuter, (PULocationID#7 = PULocationID#261), rightHint=(strategy=broadcast)
#    :     :- Aggregate [DOLocationID#8, PULocationID#7, trip_distance#4, VendorID#0, dropoff_datetime#60, pickup_datetime#59], [VendorID#0, pickup_datetime#59, dropoff_datetime#60, PULocationID#7, DOLocationID#8, first(passenger_count#65, false) AS passenger_count#566, trip_distance#4, first(fare_amount#10, false) AS fare_amount#568, first(total_amount#16, false) AS total_amount#570, first(source_file#21, false) AS source_file#572, first(2026-03-01 22:13:45.631371, false) AS ingested_at#574, round((cast((unix_timestamp(dropoff_datetime#60, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_datetime#59, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as decimal(20,0)) / 60.0), 2) AS trip_duration_minutes#230, cast(pickup_datetime#59 as date) AS pickup_date#231]
#    :     :  +- Project [VendorID#0, cast(tpep_pickup_datetime#1 as timestamp) AS pickup_datetime#59, cast(tpep_dropoff_datetime#2 as timestamp) AS dropoff_datetime#60, PULocationID#7, DOLocationID#8, cast(passenger_count#3L as int) AS passenger_count#65, trip_distance#4, fare_amount#10, total_amount#16, source_file#21]
#    :     :     +- Filter ((((((isnotnull(tpep_pickup_datetime#1) AND isnotnull(tpep_dropoff_datetime#2)) AND isnotnull(trip_distance#4)) AND isnotnull(passenger_count#3L)) AND isnotnull(total_amount#16)) AND isnotnull(fare_amount#10)) AND (((((((isnotnull(cast(tpep_pickup_datetime#1 as timestamp)) AND isnotnull(cast(tpep_dropoff_datetime#2 as timestamp))) AND (cast(tpep_dropoff_datetime#2 as timestamp) > cast(tpep_pickup_datetime#1 as timestamp))) AND (trip_distance#4 > 0.0)) AND (cast(passenger_count#3L as int) > 0)) AND ((total_amount#16 > 0.0) AND (fare_amount#10 > 0.0))) AND isnotnull(PULocationID#7)) AND isnotnull(DOLocationID#8)))
#    :     :        +- Project [VendorID#0, tpep_pickup_datetime#1, tpep_dropoff_datetime#2, passenger_count#3L, trip_distance#4, PULocationID#7, DOLocationID#8, fare_amount#10, total_amount#16, input_file_name() AS source_file#21]
#    :     :           +- Relation [VendorID#0,tpep_pickup_datetime#1,tpep_dropoff_datetime#2,passenger_count#3L,trip_distance#4,RatecodeID#5L,store_and_fwd_flag#6,PULocationID#7,DOLocationID#8,payment_type#9L,fare_amount#10,extra#11,mta_tax#12,tip_amount#13,tolls_amount#14,improvement_surcharge#15,total_amount#16,congestion_surcharge#17,Airport_fee#18,cbd_congestion_fee#19] parquet
#    :     +- Project [cast(LocationID#22L as int) AS PULocationID#261, Zone#24 AS pickup_zone#262, Borough#23 AS pickup_borough#263]
#    :        +- Filter isnotnull(cast(LocationID#22L as int))
#    :           +- Relation [LocationID#22L,Borough#23,Zone#24,service_zone#25] parquet
#    +- Project [cast(LocationID#267L as int) AS DOLocationID#264, Zone#269 AS dropoff_zone#265, Borough#268 AS dropoff_borough#266]
#       +- Filter isnotnull(cast(LocationID#267L as int))
#          +- Relation [LocationID#267L,Borough#268,Zone#269,service_zone#270] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [VendorID#0, pickup_datetime#59, dropoff_datetime#60, PULocationID#7, DOLocationID#8, pickup_zone#262, pickup_borough#263, dropoff_zone#265, dropoff_borough#266, passenger_count#566, trip_distance#4, fare_amount#568, total_amount#570, trip_duration_minutes#230, pickup_date#231, source_file#572, ingested_at#574]
#    +- BroadcastHashJoin [DOLocationID#8], [DOLocationID#264], LeftOuter, BuildRight, false
#       :- Project [PULocationID#7, VendorID#0, pickup_datetime#59, dropoff_datetime#60, DOLocationID#8, passenger_count#566, trip_distance#4, fare_amount#568, total_amount#570, source_file#572, ingested_at#574, trip_duration_minutes#230, pickup_date#231, pickup_zone#262, pickup_borough#263]
#       :  +- BroadcastHashJoin [PULocationID#7], [PULocationID#261], LeftOuter, BuildRight, false
#       :     :- SortAggregate(key=[DOLocationID#8, PULocationID#7, trip_distance#4, VendorID#0, dropoff_datetime#60, pickup_datetime#59], functions=[first(passenger_count#65, false), first(fare_amount#10, false), first(total_amount#16, false), first(source_file#21, false), first(2026-03-01 22:13:45.631371, false)], output=[VendorID#0, pickup_datetime#59, dropoff_datetime#60, PULocationID#7, DOLocationID#8, passenger_count#566, trip_distance#4, fare_amount#568, total_amount#570, source_file#572, ingested_at#574, trip_duration_minutes#230, pickup_date#231])
#       :     :  +- Sort [DOLocationID#8 ASC NULLS FIRST, PULocationID#7 ASC NULLS FIRST, trip_distance#4 ASC NULLS FIRST, VendorID#0 ASC NULLS FIRST, dropoff_datetime#60 ASC NULLS FIRST, pickup_datetime#59 ASC NULLS FIRST], false, 0
#       :     :     +- Exchange hashpartitioning(DOLocationID#8, PULocationID#7, trip_distance#4, VendorID#0, dropoff_datetime#60, pickup_datetime#59, 200), ENSURE_REQUIREMENTS, [plan_id=1897]
#       :     :        +- SortAggregate(key=[DOLocationID#8, PULocationID#7, knownfloatingpointnormalized(normalizenanandzero(trip_distance#4)) AS trip_distance#4, VendorID#0, dropoff_datetime#60, pickup_datetime#59], functions=[partial_first(passenger_count#65, false), partial_first(fare_amount#10, false), partial_first(total_amount#16, false), partial_first(source_file#21, false), partial_first(2026-03-01 22:13:45.631371, false)], output=[DOLocationID#8, PULocationID#7, trip_distance#4, VendorID#0, dropoff_datetime#60, pickup_datetime#59, first#585, valueSet#586, first#587, valueSet#588, first#589, valueSet#590, first#591, valueSet#592, first#593, valueSet#594])
#       :     :           +- Sort [DOLocationID#8 ASC NULLS FIRST, PULocationID#7 ASC NULLS FIRST, knownfloatingpointnormalized(normalizenanandzero(trip_distance#4)) AS trip_distance#4 ASC NULLS FIRST, VendorID#0 ASC NULLS FIRST, dropoff_datetime#60 ASC NULLS FIRST, pickup_datetime#59 ASC NULLS FIRST], false, 0
#       :     :              +- Project [VendorID#0, cast(tpep_pickup_datetime#1 as timestamp) AS pickup_datetime#59, cast(tpep_dropoff_datetime#2 as timestamp) AS dropoff_datetime#60, PULocationID#7, DOLocationID#8, cast(passenger_count#3L as int) AS passenger_count#65, trip_distance#4, fare_amount#10, total_amount#16, source_file#21]
#       :     :                 +- Filter ((((((isnotnull(tpep_pickup_datetime#1) AND isnotnull(tpep_dropoff_datetime#2)) AND isnotnull(trip_distance#4)) AND isnotnull(passenger_count#3L)) AND isnotnull(total_amount#16)) AND isnotnull(fare_amount#10)) AND (((((((isnotnull(cast(tpep_pickup_datetime#1 as timestamp)) AND isnotnull(cast(tpep_dropoff_datetime#2 as timestamp))) AND (cast(tpep_dropoff_datetime#2 as timestamp) > cast(tpep_pickup_datetime#1 as timestamp))) AND (trip_distance#4 > 0.0)) AND (cast(passenger_count#3L as int) > 0)) AND ((total_amount#16 > 0.0) AND (fare_amount#10 > 0.0))) AND isnotnull(PULocationID#7)) AND isnotnull(DOLocationID#8)))
#       :     :                    +- Project [VendorID#0, tpep_pickup_datetime#1, tpep_dropoff_datetime#2, passenger_count#3L, trip_distance#4, PULocationID#7, DOLocationID#8, fare_amount#10, total_amount#16, input_file_name() AS source_file#21]
#       :     :                       +- FileScan parquet [VendorID#0,tpep_pickup_datetime#1,tpep_dropoff_datetime#2,passenger_count#3L,trip_distance#4,PULocationID#7,DOLocationID#8,fare_amount#10,total_amount#16] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(2 paths)[file:/home/jovyan/data/inbox/yellow_tripdata_2025-01.parquet, file:/ho..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<VendorID:int,tpep_pickup_datetime:timestamp_ntz,tpep_dropoff_datetime:timestamp_ntz,passen...
#       :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=1901]
#       :        +- Project [cast(LocationID#22L as int) AS PULocationID#261, Zone#24 AS pickup_zone#262, Borough#23 AS pickup_borough#263]
#       :           +- Filter isnotnull(cast(LocationID#22L as int))
#       :              +- FileScan parquet [LocationID#22L,Borough#23,Zone#24] Batched: true, DataFilters: [isnotnull(cast(LocationID#22L as int))], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/data/inbox/taxi_zone_lookup.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<LocationID:bigint,Borough:string,Zone:string>
#       +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)),false), [plan_id=1905]
#          +- Project [cast(LocationID#267L as int) AS DOLocationID#264, Zone#269 AS dropoff_zone#265, Borough#268 AS dropoff_borough#266]
#             +- Filter isnotnull(cast(LocationID#267L as int))
#                +- FileScan parquet [LocationID#267L,Borough#268,Zone#269] Batched: true, DataFilters: [isnotnull(cast(LocationID#267L as int))], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/data/inbox/taxi_zone_lookup.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<LocationID:bigint,Borough:string,Zone:string>
